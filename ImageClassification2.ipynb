# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
# load the model
model = VGG16()
# load an image from file
#image = load_img('15564192784_63a16b5d86_o.jpg', target_size=(224, 224))
# convert the image pixels to a numpy array
#image = img_to_array(image)
# reshape data for the model
#image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
#image = preprocess_input(image)
# predict the probability across all output classes
#yhat = model.predict(image)
# convert the probabilities to class labels
#label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
#label = label[0][0]
# print the classification
#print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From E:\anacondainstallation\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
import os
os.chdir(r'F:\mldata\final\data\pic')

# %%
os.listdir()
# Out:
# ['10155271865_898cfcf33f_o.jpg',
#  '10235901325_5071471abe_o.jpg',
#  '10650461226_be349fdc82_o.jpg',
#  '109443289_b3edb30465_o.jpg',
#  '109877767_ff8f921b95_o.jpg',
#  '11123420286_9cf9721393_o.jpg',
#  '11231046476_bb82514693_o.jpg',
#  '112568527_4afd965e6d_o.jpg',
#  '11514630585_74f4c5e184_o.jpg',
#  '11708063423_81a066c484_o.jpg',
#  '11708063913_5edf0f01e8_o.jpg',
#  '11754223025_f763772dbc_o.jpg',
#  '11754477983_3eecc2943c_o.jpg',
#  '11754485183_1b697acd0d_o.jpg',
#  '119690924_a1912f7c24_o.jpg',
#  '12033135565_14ba4d9c95_o.jpg',
#  '12098053775_090a1b36cc_o.jpg',
#  '12548089955_7c81839c29_o.jpg',
#  '12640641345_461bc32408_o.jpg',
#  '1322285840_13371404fb_o.jpg',
#  '1343073542_808b3222c1_o.jpg',
#  '13433039245_d0482ca360_o.jpg',
#  '13433154473_5b3c8dd57e_o.jpg',
#  '13433154703_86062cfce4_o.jpg',
#  '13433402814_9c6dd7ef74_o.jpg',
#  '13438327003_65ca1bfed6_o.jpg',
#  '13640788213_4a3ba90cf5_o.jpg',
#  '13646245233_76a9c4e40f_o.jpg',
# ...

# %%
image = load_img('211962450_317eda6dbc_o.jpg', target_size=(224, 224))
# convert the image pixels to a numpy array
image = img_to_array(image)
# reshape data for the model
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
image = preprocess_input(image)
# predict the probability across all output classes
yhat = model.predict(image)
# convert the probabilities to class labels
label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
label = label[0][0]
# print the classification
print('%s (%.2f%%)' % (label[1], label[2]*100))
# Out:
# church (77.82%)

# %%
os.chdir(r'F:\mldata\final\data\pic')

# %%
os.listdir()

# %%
def label_img(img): 
    img_label = img.split('.')[0]
    return img_label

# %%
data_fol_p=r'F:\mldata\final\data\pic'
base=r'F:\mldata\final\data\folder'

# %%
from shutil import move
image=[]
image_l=[]
fro_path=[]
to_path=[]
for i in os.listdir(data_fol_p):
    imglabel=i
    label=image_clasify(i)
    flabel=label.split('_')[0]
    label=flabel.lower()
    fp=os.path.join(data_fol_p,i)
    if not os.path.exists(os.path.join(base,label)):
        os.mkdir(os.path.join(base,label))
    tp=os.path.join(os.path.join(base,label),i)
    image.append(imglabel)
    image_l.append(label)
    fro_path.append(fp)
    to_path.append(tp)
    move(fp,tp)

# %%
def image_clasify(imagename):
    image = load_img(imagename, target_size=(224, 224))
# convert the image pixels to a numpy array
    image = img_to_array(image)
# reshape data for the model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
# prepare the image for the VGG model
    image = preprocess_input(image)
# predict the probability across all output classes
    yhat = model.predict(image)
# convert the probabilities to class labels
    label = decode_predictions(yhat)
# retrieve the most likely result, e.g. highest probability
    rlabel = label[0][0]
    return rlabel[1]

# %%
os.chdir(r'F:\mldata\final\data\pic')
image_clasify('13966697923_f3a74a8c3d_o.jpg')
# Out:
# 'airliner'

# %%
image
# Out:
# ['10155271865_898cfcf33f_o.jpg',
#  '10235901325_5071471abe_o.jpg',
#  '10650461226_be349fdc82_o.jpg',
#  '109443289_b3edb30465_o.jpg',
#  '109877767_ff8f921b95_o.jpg',
#  '11123420286_9cf9721393_o.jpg',
#  '11231046476_bb82514693_o.jpg',
#  '112568527_4afd965e6d_o.jpg',
#  '11514630585_74f4c5e184_o.jpg',
#  '11708063423_81a066c484_o.jpg',
#  '11708063913_5edf0f01e8_o.jpg',
#  '11754223025_f763772dbc_o.jpg',
#  '11754477983_3eecc2943c_o.jpg',
#  '11754485183_1b697acd0d_o.jpg',
#  '119690924_a1912f7c24_o.jpg',
#  '12033135565_14ba4d9c95_o.jpg',
#  '12098053775_090a1b36cc_o.jpg',
#  '12548089955_7c81839c29_o.jpg',
#  '12640641345_461bc32408_o.jpg',
#  '1322285840_13371404fb_o.jpg',
#  '1343073542_808b3222c1_o.jpg',
#  '13433039245_d0482ca360_o.jpg',
#  '13433154473_5b3c8dd57e_o.jpg',
#  '13433154703_86062cfce4_o.jpg',
#  '13433402814_9c6dd7ef74_o.jpg',
#  '13438327003_65ca1bfed6_o.jpg',
#  '13640788213_4a3ba90cf5_o.jpg',
#  '13646245233_76a9c4e40f_o.jpg',
# ...

# %%
image_l
# Out:
# ['violin',
#  'church',
#  'airliner',
#  'laptop',
#  'violin',
#  'tabby',
#  'tabby',
#  'chihuahua',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'laptop',
#  'acoustic',
#  'church',
#  'church',
#  'airliner',
#  'airliner',
#  'arabian',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'tabby',
#  'airliner',
#  'acoustic',
#  'airliner',
#  'airliner',
#  'tabby',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'church',
#  'laptop',
#  'airliner',
#  'tabby',
#  'chihuahua',
#  'tabby',
#  'tabby',
#  'church',
#  'violin',
#  'german',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'german',
#  'airliner',
#  'airliner',
#  'airliner',
#  'church',
#  'tabby',
#  'church',
#  'chihuahua',
#  'church',
#  'airliner',
#  'chihuahua',
#  'laptop',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'airliner',
#  'church',
#  'airliner',
#  'airliner',
# ...

# %%
fro_path
# Out:
# ['F:\\mldata\\final\\data\\pic\\211962450_317eda6dbc_o.jpg',
#  'F:\\mldata\\final\\data\\pic\\2293561108_0865324750_o.jpg',
#  'F:\\mldata\\final\\data\\pic\\34442615_d709d1a2e0_o.jpg',
#  'F:\\mldata\\final\\data\\pic\\3550783104_a03016ec88_o.jpg',
#  'F:\\mldata\\final\\data\\pic\\52062370_6ea54397d1_o.jpg',
#  'F:\\mldata\\final\\data\\pic\\60113299_f80aca1d24_o.jpg',
#  'F:\\mldata\\final\\data\\pic\\8696238085_2ab9e29540_o.jpg']

# %%
to_path
# Out:
# ['F:\\mldata\\final\\data\\folder\\church\\211962450_317eda6dbc_o.jpg',
#  'F:\\mldata\\final\\data\\folder\\airliner\\2293561108_0865324750_o.jpg',
#  'F:\\mldata\\final\\data\\folder\\violin\\34442615_d709d1a2e0_o.jpg',
#  'F:\\mldata\\final\\data\\folder\\acoustic_guitar\\3550783104_a03016ec88_o.jpg',
#  'F:\\mldata\\final\\data\\folder\\laptop\\52062370_6ea54397d1_o.jpg',
#  'F:\\mldata\\final\\data\\folder\\Chihuahua\\60113299_f80aca1d24_o.jpg',
#  'F:\\mldata\\final\\data\\folder\\violin\\8696238085_2ab9e29540_o.jpg']

# %%
import numpy as np
data_fol=np.unique(image_l)

# %%
os.path()

# %%
data_fol_p

# %%
os.listdir()

# %%
from shutil import move

# %%
for i in data_fol:
    frm=data_fol_p
    to=os.path.join(data_fol_p,i)
    print(frm)
    print(to)
    os.mkdir(os.path.join(data_fol_p,i))
    move(frm,to)

# %%
for i in data_fol:
    print(i)

# %%
import os
os.chdir(r'F:\mldata\final\data\folder')

# %%
os.listdir()
# Out:
# ['acoustic_guitar', 'airliner', 'Chihuahua', 'church', 'laptop', 'violin']

# %%
for i in os.listdir():
    if os.path.exists(i):
        print(1)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %%
f=[]

# %%
f='airliner'

# %%
t=f.split('_')

# %%
t
# Out:
# ['airliner']

# %%
label='Chihuahua'

# %%
flabel=label.split('_')[0]

# %%
flabel.lower()
# Out:
# 'chihuahua'

# %%
i
# Out:
# '9885418994_d976c98902_o.jpg'

# %%
import pandas as pd
image_list=pd.DataFrame(data={'Image':image})
image_label=pd.DataFrame(data={'Image':image_l})

# %%
image_list.head()
# Out:
#                           Image
# 0  10155271865_898cfcf33f_o.jpg
# 1  10235901325_5071471abe_o.jpg
# 2  10650461226_be349fdc82_o.jpg
# 3    109443289_b3edb30465_o.jpg
# 4    109877767_ff8f921b95_o.jpg

# %%
image_label.head()
# Out:
#       Image
# 0    violin
# 1    church
# 2  airliner
# 3    laptop
# 4    violin

# %%
image_imagelabel = pd.merge(image_list, image_label, how='inner', on = image_list.index)

# %%
image_imagelabel = image_imagelabel.drop(columns=['key_0'])

# %%
image_imagelabel.head()
# Out:
#                         Image_x   Image_y
# 0  10155271865_898cfcf33f_o.jpg    violin
# 1  10235901325_5071471abe_o.jpg    church
# 2  10650461226_be349fdc82_o.jpg  airliner
# 3    109443289_b3edb30465_o.jpg    laptop
# 4    109877767_ff8f921b95_o.jpg    violin

# %%
image_imagelabel=image_imagelabel.rename(columns={'Image_x':'file','Image_y':'folder'})

# %%
image_imagelabel.head()
# Out:
#                            file    folder
# 0  10155271865_898cfcf33f_o.jpg    violin
# 1  10235901325_5071471abe_o.jpg    church
# 2  10650461226_be349fdc82_o.jpg  airliner
# 3    109443289_b3edb30465_o.jpg    laptop
# 4    109877767_ff8f921b95_o.jpg    violin

# %%
os.chdir(r'F:\mldata\final\code')
image_imagelabel.to_csv('image_folder_classification.csv',index=False)

# %%
os.listdir()
# Out:
# ['data', 'final_data', 'image_folder_classification.csv', 'New folder']

# %%
Python Code to classify the images using per-defined models and move the specific folder as labelled by the model. Attached the csv file with file and folder (image labels).
